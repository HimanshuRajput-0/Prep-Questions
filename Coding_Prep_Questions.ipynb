# %% [markdown]
# <a href="https://colab.research.google.com/github/HimanshuRajput-0/Prep-Questions/blob/main/Coding_Prep_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROBLEMS ON ARRAY :** THANKS TO TAKE YOU FORWARD

# %% [markdown]
# **Find the smallest number in the array:**

# %%
# using sort() function:

def smallernumber (arr):
  arr.sort()

  return arr[0]

if __name__ == "__main__":

  arr = [7, 9, 5, 10, 8]
  min = smallernumber(arr)

  print(f"the smallest number in the array is {min}")
# Out:
# the smallest number in the array is 5

# %% [markdown]
# ```
# Time Complexity: O(N log N), where N is the size of the array, as we are sorting the array.
#
# Space Complexity: O(1), as we are using a constant.
# ```

# %% [markdown]
# ```OR```

# %%
# using optimal approach:

def smallestnumber (arr):
  min = arr[0]

  for i in range(len(arr)):
    if min>arr[i]:
      min = arr[i]

  return min

if __name__ == "__main__":

  arr = [7, 9, 5, 10, 8]
  min = smallestnumber(arr)

  print(f"the smallest number in the array is {min}")
# Out:
# the smallest number in the array is 5

# %% [markdown]
# ```
# Time Complexity: O(N), where N is the size of the array, as we are iterating through the array once.
#
# Space Complexity: O(1), as we are using a constant.
# ```

# %% [markdown]
# **Find the largest number in the array:**

# %%
# using sort() function:

def largestnumber (arr):
  arr.sort()

  return arr[-1]

if __name__ == "__main__":

  arr = [8, 10, 5, 7, 9]

  max = largestnumber(arr)
  print(f"the largest number in this array is {max}")
# Out:
# the largest number in this array is 10

# %% [markdown]
# ```
# Time Complexity: O(N log N), where N is the size of the array, as we are sorting the array.
#
# Space Complexity: O(1), as we are using a constant.
# ```

# %% [markdown]
# ```OR```

# %%
def largestnumber (arr):

  max = arr[0]

  for i in range(len(arr)):
    if max<arr[i]:
      max = arr[i]

  return max

if __name__ == "__main__":

  arr = [8, 10, 5, 7, 9]

  max = largestnumber(arr)
  print(f"the largest number in this array is {max}")
# Out:
# the largest number in this array is 10

# %% [markdown]
# ```
# Time Complexity: O(N), where N is the size of the array, as we are iterating through the array once.
#
# Space Complexity: O(1), as we are using a constant.
# ```

# %% [markdown]
# **Find Second Smallest and Second Largest Element in an array :**

# %%
# using sort() function:

def secondsmallestandLargestnum (arr):

  arr.sort()

  secondmin = arr[1]
  secondmax = arr[-2]

  return secondmin, secondmax

if __name__ =="__main__":

  arr = [8, 10, 5, 7, 9]

  secondmin, secondmax = secondsmallestandLargestnum(arr)

  print(f"the second smallest number in this array is {secondmin}")
  print(f"the second largest number in this array is {secondmax}")
# Out:
# the second smallest number in this array is 7
# the second largest number in this array is 9

# %% [markdown]
# ```
# Time Complexity: O(N log N), for sorting the array.
#
# Space Complexity: O(1), as we are using a constant amount of space for variables.
# ```

# %%
# Optimal Approach:

def secondsmallestnum (arr):

  smallest = secondsmallest = float('inf')

  for i in range(len(arr)):
    if arr[i]<smallest:
      secondsmallest = smallest
      smallest = arr[i]
    elif arr[i] < secondsmallest and arr[i] != smallest:
      secondsmallest = arr[i]

  return secondsmallest

def secondlargestnum(arr):

  largest = secondlargest = float('-inf')

  for i in range(len(arr)):
    if arr[i]>largest:
      secondlargest = largest
      largest = arr[i]
    elif arr[i] > secondlargest and arr[i] != largest:
      secondlargest = arr[i]

  return secondlargest


if __name__ =="__main__":
  arr = [8, 10, 5, 7, 9]

  minresult = secondsmallestnum(arr)
  maxresult = secondlargestnum(arr)

  print(f"the second smallest number is {minresult}")
  print(f"the second largest number is {maxresult}")
# Out:
# the second smallest number is 7
# the second largest number is 9

# %% [markdown]
# ```
# Time Complexity: O(N), we do two linear traversals in our array.
#
# Space Complexity: O(1), as we are using a constant.
# ```

# %% [markdown]
# **Reverse a given array :**
